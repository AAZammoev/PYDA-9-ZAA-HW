# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
a = len(long_phrase)
b = len(short_phrase)
a > b

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах (*в мегабайте 2^20 байт*). Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*".

# %%
A = int (input ())
A = round(A / (2 ** 20), 2)
print ('Объём файла равен ' + str(A) + 'Mb')

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
A = str (input ('Введите месяц: '))
B = int (input ('Введите число: '))
if A == 'январь' and B < 21:
    print ('Вывoд: ' + 'Козерог')
if A == 'январь' and B > 21:
    print ('Вывoд: ' + 'Водолей')
if A == 'февраль' and B < 20:
    print ('Вывoд: ' + 'Водолей')
if A == 'февраль' and B > 20:
    print ('Вывoд: ' + 'Рыбы')
if A == 'март' and B < 21:
    print ('Вывoд: ' + 'Рыбы')
if A == 'март' and B > 21:
    print ('Вывoд: ' + 'Овен')
if A == 'апрель' and B < 21:
    print ('Вывoд: ' + 'Овен')
if A == 'апрель' and B > 21:
    print ('Вывoд: ' + 'Телец')
if A == 'май' and B < 22:
    print ('Вывoд: ' + 'Телец')
if A == 'май' and B > 22:
    print ('Вывoд: ' + 'Близнецы')
if A == 'июнь' and B < 22:
    print ('Вывoд: ' + 'Близнецы')
if A == 'июнь' and B > 22:
    print ('Вывoд: ' + 'Рак')
if A == 'июль' and B < 23:
    print ('Вывoд: ' + 'Рак')
if A == 'июль' and B > 23:
    print ('Вывoд: ' + 'Лев')
if A == 'август' and B < 24:
    print ('Вывoд: ' + 'Лев')
if A == 'август' and B > 24:
    print ('Вывoд: ' + 'Дева')
if A == 'сентябрь' and B < 24:
    print ('Вывoд: ' + 'Дева')
if A == 'сентябрь' and B > 24:
    print ('Вывoд: ' + 'Весы')
if A == 'октябрь' and B < 24:
    print ('Вывoд: ' + 'Весы')
if A == 'октябрь' and B > 24:
    print ('Вывoд: ' + 'Скорпион')
if A == 'ноябрь' and B < 23:
    print ('Вывoд: ' + 'Скорпион')
if A == 'ноябрь' and B > 23:
    print ('Вывoд: ' + 'Стрелец')
if A == 'декабрь' and B < 23:
    print ('Вывoд: ' + 'Стрелец')
if A == 'декабрь' and B > 23:
    print ('Вывoд: ' + 'Козерог')
# Out:
# Введите месяц: март
# Введите число: 7
# Вывoд: Рыбы

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
A = int (input ('Введите заработанную плату в месяц: '))
B = int (input ('Введите сколько процентов уходит на ипотеку: '))
C = int (input ('Введите сколько процентов уходит на жизнь: '))
D = int (input ('Введите количество премий за год: '))
x = A*12
y = x*(B/100)
z = x - y - x*(C/100) + A/2*D
print ('Вывод: На ипотеку было потрачено: ' + str(int(y)) + ' рублей Было накоплено: ' + str(int(z)) +' рублей')
# Out:
# Введите заработанную плату в месяц: 1000
# Введите сколько процентов уходит на ипотеку: 23
# Введите сколько процентов уходит на жизнь: 34
# Введите количество премий за год: 5
# Вывод: На ипотеку было потрачено: 2760 рублей Было накоплено: 7660 рублей
